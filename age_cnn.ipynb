# %%
import pandas as pd
import numpy as np
import cv2 as cv
import os

# %% [markdown]
# ## create labels of dataset

# %% [markdown]
# ### get file names

# %%
path = "/home/agathe/Documents/Bishop's/Research/project/data/"
files = os.listdir(path)
filename_list = np.array(files)

print(filename_list.shape)
# Out:
# (24104,)

# %% [markdown]
# ### parse file names to get label informations

# %%
def parse(file):
    labels = file.split("_")
    if len(labels) != 4: return
    for i in range(3):
        if labels[i].isdigit():
            labels[i] = int(labels[i])
    return labels[0:3]

labels = np.array(list(map(parse, filename_list)))
print(labels)
# Out:
# [[ 1  1  0]
#  [62  1  0]
#  [65  1  0]
#  ...
#  [45  1  0]
#  [26  1  1]
#  [29  0  1]]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## find face in image

# %% [markdown]
# ### upload image

# %%
def read_image(file):
    filepath = path + file
    img = cv.imread(filepath)
    return img

images = np.array(list(map(read_image, filename_list)))
# Out:
# Corrupt JPEG data: premature end of data segment
# libpng warning: iCCP: known incorrect sRGB profile
# Corrupt JPEG data: bad Huffman code

# %%
print(images[0])
cv.imshow('', images[0])
# Out:
# None
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[21], line 2
#       1 print(images[0])
# ----> 2 cv.imshow('', images[0])
#
# error: OpenCV(4.9.0) /io/opencv/modules/highgui/src/window.cpp:971: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'

# %%
face_cas = cv.CascadeClassifier(cv.data.haarcascades + "haarcascade_frontalface_alt.xml")

def detectDisplay(frame):
    # transform image frame
    gray = cv.cvtColor(frame, cv.COLOR_RGB2GRAY)
    gray = cv.equalizeHist(gray)

    # find faces
    faces = face_cas.detectMultiScale(gray)

    print(faces)

detectDisplay(images[0])
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[10], line 13
#       9     faces = face_cas.detectMultiScale(gray)
#      11     print(faces)
# ---> 13 detectDisplay(images[0])
#
# Cell In[10], line 5, in detectDisplay(frame)
#       3 def detectDisplay(frame):
#       4     # transform image frame
# ----> 5     gray = cv.cvtColor(frame, cv.COLOR_RGB2GRAY)
#       6     gray = cv.equalizeHist(gray)
#       8     # find faces
#
# error: OpenCV(4.9.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
